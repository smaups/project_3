# %%
import pandas as pd

# %%
population = pd.read_csv("population_1960.csv")
gdp = pd.read_csv("gdp_1960.csv")
olympics = pd.read_csv("Summer_Olympics.csv")

# %%
olympics.head()
# Out:
#    ID                Name Sex  Age  Height  Weight     Team  NOC  Year  \
# 0   1           A Dijiang   M   24     180    80.0    China  CHN  1992
# 1   2            A Lamusi   M   23     170    60.0    China  CHN  2012
# 2  12   Jyri Tapani Aalto   M   31     172    70.0  Finland  FIN  2000
# 3  13  Minna Maarit Aalto   F   30     159    55.5  Finland  FIN  1996
# 4  13  Minna Maarit Aalto   F   34     159    55.5  Finland  FIN  2000
#
#         Sport Medal_Type     Medals
# 0  Basketball    No Medal  No Medal
# 1        Judo    No Medal  No Medal
# 2   Badminton    No Medal  No Medal
# 3     Sailing    No Medal  No Medal
# 4     Sailing    No Medal  No Medal

# %%
population.head()
# Out:
#      Country Name Country Code        Series Name  Series Code      1960  \
# 0     Afghanistan          AFG  Population, total  SP.POP.TOTL   8996973
# 1         Albania          ALB  Population, total  SP.POP.TOTL   1608800
# 2         Algeria          DZA  Population, total  SP.POP.TOTL  11057863
# 3  American Samoa          ASM  Population, total  SP.POP.TOTL     20123
# 4         Andorra          AND  Population, total  SP.POP.TOTL     13411
#
#        1961      1962      1963      1964      1965  ...      2009      2010  \
# 0   9169410   9351441   9543205   9744781   9956320  ...  28394813  29185507
# 1   1659800   1711319   1762621   1814135   1864791  ...   2927519   2913021
# 2  11336339  11619828  11912803  12221675  12550885  ...  35333881  35977455
# 3     20602     21253     22034     22854     23672  ...     56683     56079
# 4     14375     15370     16412     17469     18549  ...     84463     84449
#
# ...

# %%
3
grouped = olympics.groupby[olympics["NOC"] == i and olympics["Year"] == y]

# %%
olympics_unfiltered = olympics_unfiltered[olympics_unfiltered["Year"] > 1909].reset_index()
olympics_unfiltered = olympics_unfiltered[olympics_unfiltered["Sport"] != "Art Competitions"].reset_index()
